# %%
from scipy.misc import imread

# %%
page = imread( 'whitehouse_organization.png')

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
plt.imshow(page)

# %%
projs = imread( 'whitehouse_organization_projects.png')

# %%
projs = projs[:,:750]

# %%
plt.imshow( projs)

# %%
temp = np.vstack( (projs[:270],projs[580:]) )
plt.figure( figsize=(18,12))
plt.imshow( temp )

# %%
plt.figure( figsize=(18,12))
page_final = np.copy( page )
initial_row = 380
initial_col = 0
rows, cols, channels = temp.shape
page_final[ initial_row:initial_row+rows,initial_col:initial_col+cols, :] = temp
plt.imshow( page_final )

# %%
plt.imshow( page_final[:750] )

# %%
from scipy.misc import imsave

# %%
imsave( 'whitehouse_organization_composite.png', page_final[:750])
